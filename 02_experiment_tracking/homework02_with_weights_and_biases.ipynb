# %% [markdown]
# # MLOps Zoomcamp 2023 - Session #2 - Homework with Weights & Biases
#
# Author: José Victor

# %% [markdown]
# ## Q1 Install the package
#
# To get started with Weights & Biases you'll need to install the appropriate Python package.
#
# For this we recommend creating a separate Python environment, for example, you can use conda environment, and then install the package there with `pip` or `conda`.
#
# Once you installed the package, run the command `wand --version` and check the output.
#
# What's the version that you have?

# %%
# !wandb --version
# Out:
# wandb, version 0.15.3

# %% [markdown]
# ## Q2 Download and preprocess the data
#
# We'll use the Green Taxi Trip Records dataset to predict the amount of tips for each trip.
#
# Download the data for January, February and March 2022 in parquet format from [here](https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page).
#
# Use the script `preprocess_data.py` located in the folder `homework-wandb` to preprocess the data.
#
# The script will:
#
# * initialize a Weights & Biases run.
# * load the data from the folder `<TAXI_DATA_FOLDER>` (the folder where you have downloaded the data),
# * fit a `DictVectorizer` on the training set (January 2022 data),
# * save the preprocessed datasets and the `DictVectorizer` to your Weights & Biases dashboard as an artifact of type `preprocessed_dataset`.
#
# Your task is to download the datasets and then execute this command:
#
# ```bash
# python preprocess_data.py \
#   --wandb_project <WANDB_PROJECT_NAME> \
#   --wandb_entity <WANDB_USERNAME> \
#   --raw_data_path <TAXI_DATA_FOLDER> \
#   --dest_path ./output
# ```
#
# Tip: go to `02-experiment-tracking/homework-wandb/` folder before executing the command and change the value of `<WANDB_PROJECT_NAME>` to the name of your Weights & Biases project, `<WANDB_USERNAME>` to your Weights & Biases username, and `<TAXI_DATA_FOLDER>` to the location where you saved the data.
#
# Once you navigate to the `Files` tab of your artifact on your Weights & Biases page, what's the size of the saved `DictVectorizer` file?
#
# * ( ) 54 kB
# * (X) 154 kB
# * ( ) 54 MB
# * ( ) 154 MB

# %%
# !python preprocess_data_wandb.py --wandb_project homework_mlops_zoomcamp --wandb_entity josevictor-s-scursulim --raw_data_path ./dataset --dest_path ./output
# Out:
# wandb: Currently logged in as: josevictor-s-scursulim. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /workspaces/mlops-zoomcamp2023/02_experiment_tracking/wandb/run-20230605_033858-fahn18q1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run stellar-dust-1
# wandb: ⭐️ View project at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp
# wandb: 🚀 View run at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/fahn18q1
# wandb: Adding directory to artifact (./output)... Done. 0.0s
# wandb: Waiting for W&B process to finish... (success).
# wandb: 🚀 View run stellar-dust-1 at: https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/fahn18q1
# wandb: Synced 5 W&B file(s), 0 media file(s), 6 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230605_033858-fahn18q1/logs

# %% [markdown]
# ## Q3 Train a model with Weights & Biases logging
#
# We will train a `RandomForestRegressor` (from Scikit-Learn) on the taxi dataset.
#
# We have prepared the training script `train.py` for this exercise, which can be also found in the folder `homework-wandb`.
#
# The script will:
#
# * initialize a Weights & Biases run.
# * load the preprocessed datasets by fetching them from the Weights & Biases artifact previously created,
# * train the model on the training set,
# * calculate the MSE score on the validation set and log it to Weights & Biases,
# * save the trained model and log it to Weights & Biases as a model artifact.
#
# Your task is to modify the script to enable to add Weights & Biases logging, execute the script and then check the Weights & Biases run UI to check that the experiment run was properly tracked.
#
# TODO 1: log `mse` to Weights & Biases under the key `"MSE"`
#
# TODO 2: log `regressor.pkl` as an artifact of type `model`, refer to the [official docs](https://docs.wandb.ai/guides/artifacts) in order to know more about logging artifacts.
#
# You can run the script using:
#
# ```bash
# python train.py \
#   --wandb_project <WANDB_PROJECT_NAME> \
#   --wandb_entity <WANDB_USERNAME> \
#   --data_artifact "<WAND_PROJECT_NAME>/<WANDB_USERNAME>/NYC-Taxi:v0"
# ```
#
# Tip 1: You can find the artifact address under the `Usage` tab in the respective artifact's page.
#
# Tip 2: don't modify the hyperparameters of the model to make sure that the training will finish quickly.
#
# Once you have successfully ran the script, navigate the `Overview` section of the run in the Weights & Biases UI and scroll down to the `Configs`. What is the value of the `max_depth` parameter:
#
# * ( ) 4
# * ( ) 6
# * ( ) 8
# * (X) 10

# %%
# !python train_wandb.py --wandb_project homework_mlops_zoomcamp --wandb_entity josevictor-s-scursulim --data_artifact "josevictor-s-scursulim/homework_mlops_zoomcamp/NYC-Taxi:v0"
# Out:
# wandb: Currently logged in as: josevictor-s-scursulim. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /workspaces/mlops-zoomcamp2023/02_experiment_tracking/wandb/run-20230605_034756-89vobygd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run classic-dew-10
# wandb: ⭐️ View project at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp
# wandb: 🚀 View run at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/89vobygd
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb: | 1.433 MB of 1.433 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45398
# wandb:
# wandb: 🚀 View run classic-dew-10 at: https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/89vobygd
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230605_034756-89vobygd/logs

# %% [markdown]
# ## Q4 Tune model hyperparameters
#
# Now let's try to reduce the validation error by tuning the hyperparameters of the `RandomForestRegressor` using [Weights & Biases Sweeps](https://docs.wandb.ai/guides/sweeps). We have prepared the script `sweep.py` for this exercise in the `homework-wandb` directory.
#
# Your task is to modify `sweep.py` to pass the parameters `n_estimators`, `min_samples_split` and `min_samples_leaf` from `config` to `RandomForestRegressor` inside the `run_train()` function. Then we will run the sweep to figure out not only the best of hyperparameters for training our model, but also to analyze the most optimum trends in different hyperparameters. We can run the sweep using:
#
# ```bash
# python sweep.py \
#   --wandb_project <WANDB_PROJECT_NAME> \
#   --wandb_entity <WANDB_USERNAME> \
#   --data_artifact "<WANDB_PROJECT_NAME>/<WANDB_USERNAME>/NYC-Taxi:v0"
# ```
#
# This command will run the sweep for 5 iterations using the $\textbf{Bayesian Optimization and HyperBand}$ method proposed by the paper [BOHB: Robust and Efficient Hyperparameter Optimization at Scale](https://arxiv.org/abs/1807.01774). You can take a look at the sweep on your Weights & Biases dashboard, take a look at the $\textbf{Parameter Importance Panel}$ and the $\textbf{Parallel Coordinates Plot}$ to determine, and analyze which hyperparameter is the most important:
#
# * ( ) `max_depth`
# * ( ) `n_estimators`
# * ( ) `min_samples_split`
# * (X) `min_samples_leaf`

# %%
# !python sweep.py --wandb_project homework_mlops_zoomcamp --wandb_entity josevictor-s-scursulim --data_artifact "josevictor-s-scursulim/homework_mlops_zoomcamp/NYC-Taxi:v0"
# Out:
# Create sweep with ID: e00fcm7g
# Sweep URL: https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/sweeps/e00fcm7g
# wandb: Agent Starting Run: v5t5y4q8 with config:
# wandb: 	max_depth: 8
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 8
# wandb: 	n_estimators: 15
# wandb: Currently logged in as: josevictor-s-scursulim. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /workspaces/mlops-zoomcamp2023/02_experiment_tracking/wandb/run-20230605_034218-v5t5y4q8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run colorful-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp
# wandb: 🧹 View sweep at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/sweeps/e00fcm7g
# wandb: 🚀 View run at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/v5t5y4q8
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb: | 0.150 MB of 0.150 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45631
# wandb:
# wandb: 🚀 View run colorful-sweep-1 at: https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/v5t5y4q8
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230605_034218-v5t5y4q8/logs
# wandb: Agent Starting Run: fm6fkj1u with config:
# wandb: 	max_depth: 14
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 4
# wandb: 	n_estimators: 39
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /workspaces/mlops-zoomcamp2023/02_experiment_tracking/wandb/run-20230605_034229-fm6fkj1u
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run stellar-sweep-2
# wandb: ⭐️ View project at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp
# wandb: 🧹 View sweep at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/sweeps/e00fcm7g
# wandb: 🚀 View run at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/fm6fkj1u
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb: \ 2.523 MB of 2.523 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.4484
# wandb:
# wandb: 🚀 View run stellar-sweep-2 at: https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/fm6fkj1u
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230605_034229-fm6fkj1u/logs
# wandb: Agent Starting Run: 4xpajqf3 with config:
# wandb: 	max_depth: 6
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 6
# wandb: 	n_estimators: 42
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /workspaces/mlops-zoomcamp2023/02_experiment_tracking/wandb/run-20230605_034245-4xpajqf3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run pretty-sweep-3
# wandb: ⭐️ View project at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp
# wandb: 🧹 View sweep at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/sweeps/e00fcm7g
# wandb: 🚀 View run at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/4xpajqf3
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb: \ 0.193 MB of 0.193 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45993
# wandb:
# wandb: 🚀 View run pretty-sweep-3 at: https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/4xpajqf3
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230605_034245-4xpajqf3/logs
# wandb: Agent Starting Run: 3qbpu1rr with config:
# wandb: 	max_depth: 20
# wandb: 	min_samples_leaf: 1
# wandb: 	min_samples_split: 7
# wandb: 	n_estimators: 17
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /workspaces/mlops-zoomcamp2023/02_experiment_tracking/wandb/run-20230605_034255-3qbpu1rr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run expert-sweep-4
# wandb: ⭐️ View project at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp
# wandb: 🧹 View sweep at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/sweeps/e00fcm7g
# wandb: 🚀 View run at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/3qbpu1rr
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb: | 1.262 MB of 1.265 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.46294
# wandb:
# wandb: 🚀 View run expert-sweep-4 at: https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/3qbpu1rr
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230605_034255-3qbpu1rr/logs
# wandb: Agent Starting Run: ik7vm3al with config:
# wandb: 	max_depth: 19
# wandb: 	min_samples_leaf: 3
# wandb: 	min_samples_split: 4
# wandb: 	n_estimators: 11
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /workspaces/mlops-zoomcamp2023/02_experiment_tracking/wandb/run-20230605_034313-ik7vm3al
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fresh-sweep-5
# wandb: ⭐️ View project at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp
# wandb: 🧹 View sweep at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/sweeps/e00fcm7g
# wandb: 🚀 View run at https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/ik7vm3al
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb: / 1.415 MB of 1.416 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# wandb: Run summary:
# wandb: MSE 2.45536
# wandb:
# wandb: 🚀 View run fresh-sweep-5 at: https://wandb.ai/josevictor-s-scursulim/homework_mlops_zoomcamp/runs/ik7vm3al
# wandb: Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230605_034313-ik7vm3al/logs

# %% [markdown]
# ## Q5 Link the best model to the model registry
#
# Now that we have obtained the optimal set of hyperparameters and trained the best model, we can assume that we are ready to test some of these models in production. In this exercise, you'll create a model registry and link the best model from the Sweep to the model registry.
#
# First, you will need to create a Registered Model to hold all the candidate models for your particular modeling task. You can refer to [this section](https://docs.wandb.ai/guides/models/walkthrough#1-create-a-new-registered-model) of the official docs to learn how to create a registered model using the Weights & Biases UI.
#
# Once you have created the Registered Model successfully, you can navigate to the best run of your sweep, navigate to the model artifact created by the particular run, and click on the Link to Registry option from the UI. This would link the model artifact to the Registered Model. You can choose to add some suitable aliases for the Registered Model, such as `production`, `best`, etc.
#
# Now that the model artifact is linked to the Registered Model, which of these information do we see on the Registered Model UI?
#
# * (X) Versioning
# * ( ) Metadata
# * (X) Aliases
# * (X) Metric (MSE)
# * ( ) Source run
# * ( ) All of these
# * ( ) None of these
